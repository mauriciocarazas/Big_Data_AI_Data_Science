# %%
# !git clone https://github.com/mrlibw/ControlGAN.git
# Out:
# Cloning into 'ControlGAN'...
# remote: Enumerating objects: 32, done.
# remote: Counting objects: 100% (32/32), done.
# remote: Compressing objects: 100% (24/24), done.
# remote: Total 32 (delta 5), reused 32 (delta 5), pack-reused 0
# Unpacking objects: 100% (32/32), done.

# %%
# !cd ControlGAN/data/
# !wget http://www.vision.caltech.edu/visipedia-data/CUB-200-2011/CUB_200_2011.tgz
# Out:
# --2021-07-01 06:00:24--  http://www.vision.caltech.edu/visipedia-data/CUB-200-2011/CUB_200_2011.tgz
# Resolving www.vision.caltech.edu (www.vision.caltech.edu)... 34.208.54.77
# Connecting to www.vision.caltech.edu (www.vision.caltech.edu)|34.208.54.77|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://drive.google.com/file/d/1hbzc_P1FuxMkcabkgn9ZKinBwW683j45/view [following]
# --2021-07-01 06:00:24--  https://drive.google.com/file/d/1hbzc_P1FuxMkcabkgn9ZKinBwW683j45/view
# Resolving drive.google.com (drive.google.com)... 74.125.124.102, 74.125.124.138, 74.125.124.113, ...
# Connecting to drive.google.com (drive.google.com)|74.125.124.102|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘CUB_200_2011.tgz.1’
#
# CUB_200_2011.tgz.1      [ <=>                ]  63.89K  --.-KB/s    in 0.001s
#
# 2021-07-01 06:00:25 (80.2 MB/s) - ‘CUB_200_2011.tgz.1’ saved [65420]

# %%
# !ls
# Out:
# ControlGAN  sample_data
